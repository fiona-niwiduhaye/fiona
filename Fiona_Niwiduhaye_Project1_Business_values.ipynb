# %% [markdown]
# <a href="https://colab.research.google.com/github/fiona-niwiduhaye/fiona/blob/master/Fiona_Niwiduhaye_Project1_Business_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ed**-**Tech** **Analysis**

# %% [markdown]
#  In thi sanlysis we are going to use datset(EdData) provided to make analysis about Which countries have a high customer potential for our services?
# For each of these countries, what will be the evolution of this customer potential?
# In which countries should one set up first?

# %% [markdown]
# # **Import** **important** **libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Mount google drive**

# %%
from google.colab import drive

# %%
drive.mount("/content/gdrive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AX4XfWjZSzXvCas2Gzbnl8i74rsneyAKav4JqbETSdTjrWaIZKxrMuZDedI
# Mounted at /content/gdrive

# %% [markdown]
# # **Read Dataset**

# %%
#countries = pd.read_csv('/content/EdStatsCountry.csv')
#series = pd.read_csv('/content/EdStatsSeries.csv')
#footnote = pd.read_csv('/content/EdStatsFootNote.csv')
#country_series = pd.read_csv('/content/EdStatsCountry-Series.csv')
EdStatsData  = pd.read_csv('/content/drive/MyDrive/EdStatsData.csv')

# %%
EdStatsData.head()

# %%
EdStatsData  = EdStatsData.rename(columns={"Indicator Code": "Indicator_Code"})

# %% [markdown]
# #**Validate** **the** **quality** **of** **this** **dataset**

# %%
EdStatsData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %% [markdown]
# There five datsets that is provided but I have found that only one dataset called EdData has levevant neede information to come up with the analysis anafotunalyt also there a lot of NanN values and gaps  in the dataset which make assignment complicated on point of making data cleaning.

# %% [markdown]
# # **Description of Data**

# %%
EdStatsData
# Out:
#        Country Name Country Code  ... 2100 Unnamed: 69
# 0        Arab World          ARB  ...  NaN         NaN
# 1        Arab World          ARB  ...  NaN         NaN
# 2        Arab World          ARB  ...  NaN         NaN
# 3        Arab World          ARB  ...  NaN         NaN
# 4        Arab World          ARB  ...  NaN         NaN
# ...             ...          ...  ...  ...         ...
# 886925     Zimbabwe          ZWE  ...  NaN         NaN
# 886926     Zimbabwe          ZWE  ...  NaN         NaN
# 886927     Zimbabwe          ZWE  ...  NaN         NaN
# 886928     Zimbabwe          ZWE  ...  NaN         NaN
# 886929     Zimbabwe          ZWE  ...  NaN         NaN
#
# [886930 rows x 70 columns]

# %% [markdown]
# Datasets contain 886930 rows and 70 columns

# %% [markdown]
# # **Selecting Relevant information**

# %% [markdown]
# In order to find levelant information I have choosen to use indicators so that I can have need information to analysis the promp

# %%
Rwanda = EdStatsData[EdStatsData["Country Name"] == "Rwanda"]

# %%
EdStatsData  = EdStatsData.rename(columns={"Indicator Code": "Indicator_Code"})

# %%
ind1 = EdStatsData[EdStatsData["Indicator_Code"]==     "SE.ADT.1524.LT.ZS"] #Youth literacy rate, population 15-24 years, both sexes (%)
ind1 = ind1.dropna(axis=1, how='all')
ind1 = ind1.T.fillna(ind1.mean(axis=1)).T

# %%
ind1 = ind1.drop(ind1.columns[[0, 2, 3]], axis=1)

# %%
ind1 = ind1.set_index('Country Code')

# %%
ind1.dropna()
# Out:
#                  1970     1975     1976  ...     2014     2015     2016
# Country Code                             ...
# ARB           81.1817  81.1817  81.1817  ...  88.9647  81.1817  81.1817
# EAS           97.0245  97.0245  97.0245  ...  99.0044  97.0245  97.0245
# EAP           96.8072  96.8072  96.8072  ...  98.9691  96.8072  96.8072
# ECS           99.3685  99.3685  99.3685  ...  99.7114  99.3685  99.3685
# ECA           98.9582  98.9582  98.9582  ...  99.6261  98.9582  98.9582
# ...               ...      ...      ...  ...      ...      ...      ...
# VNM           94.9569  94.9569  94.9569  ...  94.9569  94.9569  94.9569
# PSE           99.0516  99.0516  99.0516  ...  99.3635  99.3406  99.3837
# YEM           60.2221  60.2221  60.2221  ...  60.2221  60.2221  60.2221
# ZMB           71.5383  71.5383  71.5383  ...  71.5383  71.5383  71.5383
# ZWE            91.448   91.448   91.448  ...  90.4281   91.448   91.448
#
# [184 rows x 43 columns]

# %%
ind1 = ind1.T

# %%
indicators["Indicator Name"]

# %%
list_indicator = EdStatsData["Indicator Name"].unique()
list_code = EdStatsData["Indicator_Code"].unique()

list_indicator_15_24 = []
list_code_15_24 = []
list_indicator_25_29 = []
list_code_25_29 = []

for i in range(len(list_indicator)):
    if "15-24" in list_indicator[i]:
        list_indicator_15_24.append(list_indicator[i])
        list_code_15_24.append(list_code[i])
    #if "25-29" in list[i]:
        list_indicator_25_29.append(list_indicator[i])
        list_code_25_29.append(list_code[i])

# %%
list_indicator_15_24
list_code_15_24
# Out:
# ['SP.POP.1524.FE.UN',
#  'SP.POP.1524.MA.UN',
#  'SP.POP.1524.TO.UN',
#  'UIS.LPP.AG15T24',
#  'UIS.LP.AG15T24',
#  'UIS.LP.AG15T24.F',
#  'UIS.LP.AG15T24.M',
#  'SE.ADT.1524.LT.ZS',
#  'SE.ADT.1524.LT.FE.ZS',
#  'SE.ADT.1524.LT.FM.ZS',
#  'SE.ADT.1524.LT.MA.ZS']

# %%
df_15_24 = EdStatsData[EdStatsData.Indicator_Code.isin(list_code_15_24)]
df_15_24 = df_15_24.dropna(axis=1, how='all')

# %%
df_15_24.to_csv("df_15_24")

# %%
list_indicator_15_24
# Out:
# ['Population, ages 15-24, female',
#  'Population, ages 15-24, male',
#  'Population, ages 15-24, total',
#  'Youth illiterate population, 15-24 years, % female',
#  'Youth illiterate population, 15-24 years, both sexes (number)',
#  'Youth illiterate population, 15-24 years, female (number)',
#  'Youth illiterate population, 15-24 years, male (number)',
#  'Youth literacy rate, population 15-24 years, both sexes (%)',
#  'Youth literacy rate, population 15-24 years, female (%)',
#  'Youth literacy rate, population 15-24 years, gender parity index (GPI)',
#  'Youth literacy rate, population 15-24 years, male (%)']

# %%
df_15_24.tail()
# Out:
#        Country Name Country Code  ... 2015 2016
# 886925     Zimbabwe          ZWE  ...  NaN  NaN
# 886926     Zimbabwe          ZWE  ...  NaN  NaN
# 886927     Zimbabwe          ZWE  ...  NaN  NaN
# 886928     Zimbabwe          ZWE  ...  NaN  NaN
# 886929     Zimbabwe          ZWE  ...  NaN  NaN
#
# [5 rows x 47 columns]

# %%
df_15_24.plot()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# After analysing the dataset which  is like an empty dataset because there is a alot of missing data in it and this make things complicated because while I was clearing data I find that droping some rows and columns will make me stay with zero data to analys.Another this is that the graph I have tried to draw is not in a good condition in a way I can make decision on it as long as there is a lot of scale on it.Again I have found that countries with data goes in many years ago means in 19 century yet we can not relay on that information by recomending a company to expand their activity in that country moreover there is a big number of illiterate people hence the program of that company has nothing to with them as long as they offer online studies.
#
# I would like to ask next time to find datasey with enough information for us to be able to come up with useful analysis.
